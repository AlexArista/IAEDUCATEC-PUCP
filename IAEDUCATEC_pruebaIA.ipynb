# %%
# Install ktrain
# !pip install ktrain

# Load dataset
from sklearn.datasets import fetch_20newsgroups
remove = ('headers', 'footers', 'quotes')
newsgroups_train = fetch_20newsgroups(subset='train', remove=remove)
newsgroups_test = fetch_20newsgroups(subset='test', remove=remove)
docs = newsgroups_train.data + newsgroups_test.data

# Import and use ktrain
import ktrain
from ktrain import text

# Now you can proceed with using ktrain for your text classification tasks

# %% [markdown]
# **TEST 1: CONSULTAS PARA MIDJOURNEY**

# %%
docs = open('Midjourney_test1.txt')

# %%
docs = ['''¿Qué es Midjourney?
Midjourney es un programa de inteligencia artificial (IA) que permite a los usuarios crear imágenes a partir de descripciones textuales. Es similar a otros programas de IA generativa, como Dall-e 2 de OpenAI y Imagen de Google AI.
Cómo funciona Midjourney
Midjourney utiliza un modelo de aprendizaje automático para generar imágenes a partir de texto. El modelo está entrenado en un conjunto de datos masivo de imágenes y texto, y puede aprender a identificar patrones en las imágenes y traducirlos a texto.
Cuando un usuario le da una descripción textual a Midjourney, el modelo genera una serie de imágenes posibles. El usuario puede entonces seleccionar la imagen que más le guste.
Pasos para usar Midjourney
Para usar Midjourney, los usuarios deben primero registrarse en el sitio web de Midjourney. Una vez registrados, pueden acceder al bot de Midjourney en Discord.
Para generar una imagen con Midjourney, los usuarios deben seguir estos pasos:
Enviar un mensaje al bot de Midjourney con una descripción textual de la imagen que desean crear.
El bot generará una serie de imágenes posibles.
El usuario puede seleccionar la imagen que más le guste.
Beneficios de Midjourney
Midjourney tiene una serie de beneficios, entre los que se incluyen:
Permite a los usuarios crear imágenes de forma rápida y sencilla.
Es capaz de generar imágenes de alta calidad.
Es versátil y puede utilizarse para crear una amplia gama de imágenes, desde paisajes hasta retratos.
Desventajas de Midjourney
Midjourney también tiene algunas desventajas, entre las que se incluyen:
Todavía está en desarrollo, por lo que puede generar imágenes inexactas o distorsionadas.
Puede ser caro, ya que los usuarios deben pagar una suscripción para acceder a las funciones completas.
Otros datos
Midjourney fue lanzado en febrero de 2022.
Está desarrollado por un equipo de investigadores e ingenieros de Suecia.
Está disponible en inglés.
Conclusión
Midjourney es una herramienta potente que puede utilizarse para crear imágenes de forma rápida y sencilla. Es una opción viable para artistas, diseñadores y cualquier persona que quiera crear imágenes creativas.''',
'''De acuerdo, aquí hay algunos datos adicionales sobre Midjourney:
Midjourney utiliza un modelo de aprendizaje automático llamado Diffusion Models. Estos modelos funcionan generando imágenes aleatorias y luego refinando esas imágenes para que coincidan con una descripción textual.
Midjourney está entrenado en un conjunto de datos masivo de imágenes y texto. Este conjunto de datos incluye imágenes de todo tipo, desde paisajes hasta retratos.
Midjourney es capaz de generar imágenes de alta calidad. Las imágenes generadas por Midjourney son generalmente realistas y detalladas.
Midjourney es versátil y puede utilizarse para crear una amplia gama de imágenes. Se puede utilizar para crear paisajes, retratos, obras de arte abstractas y mucho más.
Midjourney está disponible en inglés. Sin embargo, hay una comunidad activa de usuarios de Midjourney que traducen las descripciones textuales al español y otros idiomas.
Aquí hay algunos ejemplos de imágenes generadas por Midjourney:
Un paisaje de un bosque con un lago en el centro.
Un retrato de una mujer con el pelo largo y rubio.
Una obra de arte abstracta con colores vivos.
Midjourney es una herramienta potente que puede utilizarse para crear imágenes creativas. Es una opción viable para artistas, diseñadores y cualquier persona que quiera crear imágenes impresionantes.
Aquí hay algunos consejos para usar Midjourney:
Sé específico con tus descripciones textuales. Cuanto más específico seas, más probable es que Midjourney genere una imagen que coincida con tus expectativas.
Experimenta con diferentes descripciones textuales. No tengas miedo de experimentar con diferentes descripciones textuales para ver qué puedes crear.
Usa los comandos de Midjourney para personalizar tus imágenes. Midjourney tiene una serie de comandos que puedes usar para personalizar tus imágenes. Por ejemplo, puedes usar el comando style para cambiar el estilo de una imagen o el comando color para cambiar los colores de una imagen.
Espero que esta información sea útil.''']

# %%
print(docs)
# Out:
# ['¿Qué es Midjourney?\nMidjourney es un programa de inteligencia artificial (IA) que permite a los usuarios crear imágenes a partir de descripciones textuales. Es similar a otros programas de IA generativa, como Dall-e 2 de OpenAI y Imagen de Google AI.\nCómo funciona Midjourney\nMidjourney utiliza un modelo de aprendizaje automático para generar imágenes a partir de texto. El modelo está entrenado en un conjunto de datos masivo de imágenes y texto, y puede aprender a identificar patrones en las imágenes y traducirlos a texto.\nCuando un usuario le da una descripción textual a Midjourney, el modelo genera una serie de imágenes posibles. El usuario puede entonces seleccionar la imagen que más le guste.\nPasos para usar Midjourney\nPara usar Midjourney, los usuarios deben primero registrarse en el sitio web de Midjourney. Una vez registrados, pueden acceder al bot de Midjourney en Discord.\nPara generar una imagen con Midjourney, los usuarios deben seguir estos pasos:\nEnviar un mensaj
# ...

# %%
# INDEXDIR = '/tmp/myindex'
INDEXDIR = '/tmp/myindex2'
text.SimpleQA.initialize_index(INDEXDIR)
text.SimpleQA.index_from_list(docs,INDEXDIR,commit_every=len(docs))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
qa = text.SimpleQA(INDEXDIR)

# %%
answers = qa.ask('cuáles son los beneficios de Midjourney')
qa.display_answers(answers[:5])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Candidate Answer</th>
#       <th>Context</th>
#       <th>Confidence</th>
#       <th>Document Reference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ne una serie de beneficios</td>
# ...

# %% [markdown]
# **TEST 2: CONSULTAS PARA SYNTHESIA**

# %%
docs = open('Synthesia_test2.txt')

# %%
docs = ['''Synthesia IA es una nueva versión de Synthesia que utiliza inteligencia artificial para mejorar la experiencia de aprendizaje. El programa utiliza un modelo de aprendizaje automático para generar una visualización de las notas que se están tocando en tiempo real, así como una versión sintética del sonido del piano.
Cómo funciona Synthesia IA
Synthesia IA utiliza un modelo de aprendizaje automático llamado DeepMind Magenta. Este modelo funciona aprendiendo patrones en los vídeos de personas tocando el piano, así como en las grabaciones de audio de piano.
Cuando un usuario toca una nota en el piano, el modelo genera una visualización de la nota que se está tocando. La visualización se muestra en la pantalla del ordenador o del dispositivo móvil del usuario. El modelo también genera una versión sintética del sonido del piano, que se reproduce a través de los altavoces del ordenador o del dispositivo móvil del usuario.
Pasos para usar Synthesia IA
Para usar Synthesia IA, los usuarios deben primero instalar el programa en su ordenador o dispositivo móvil. Una vez instalado, los usuarios pueden seguir estos pasos para comenzar a aprender a tocar el piano:
Elegir una canción. Synthesia IA tiene una biblioteca de canciones que los usuarios pueden aprender a tocar.
Seleccionar un nivel de dificultad. Synthesia IA tiene diferentes niveles de dificultad para adaptarse a los diferentes niveles de habilidad de los usuarios.
Comenzar a tocar. Synthesia IA generará una visualización de las notas que se están tocando en tiempo real, así como una versión sintética del sonido del piano.
Beneficios de Synthesia IA
Synthesia IA tiene una serie de beneficios, entre los que se incluyen:
Es un método más divertido y eficaz para aprender a tocar el piano.
Es más accesible para personas de todos los niveles de habilidad.
Es más personalizable para adaptarse a las necesidades individuales del usuario.
Desventajas de Synthesia IA
Synthesia IA también tiene algunas desventajas, entre las que se incluyen:
Puede ser más caro, ya que los usuarios deben pagar una suscripción para acceder a todas las funciones.
No es tan realista como tocar el piano en un piano real.
Otros datos
Synthesia IA fue lanzado en 2023.
Está desarrollado por un equipo de desarrolladores de software en Suecia.
Está disponible en inglés, español, francés, alemán, italiano y japonés.
Conclusión
Synthesia IA es una herramienta eficaz para aprender a tocar el piano. Es un método más divertido y accesible que puede adaptarse a las necesidades individuales del usuario.''',
'''Datos adicionales
Synthesia IA utiliza un modelo de aprendizaje automático llamado DeepMind Magenta. Este modelo funciona aprendiendo patrones en los vídeos de personas tocando el piano, así como en las grabaciones de audio de piano.
Synthesia IA tiene una comunidad activa de usuarios que comparten consejos y tutoriales. Esta comunidad puede ser una fuente de inspiración y apoyo para los usuarios de Synthesia IA.
Synthesia IA se está desarrollando constantemente. El equipo de desarrollo de Synthesia IA está trabajando para mejorar la precisión y la calidad de la visualización de las notas, así como la calidad del sonido sintético.
Ejemplos de cómo se utiliza Synthesia IA
Personas que están aprendiendo a tocar el piano. Synthesia IA es una herramienta eficaz para aprender los fundamentos del piano.
Profesores de piano. Synthesia IA puede utilizarse como una herramienta de enseñanza para los profesores de piano.
Personas que quieren practicar el piano. Synthesia IA puede utilizarse para practicar canciones conocidas o para aprender nuevas canciones.
Consejos para usar Synthesia IA
Elige una canción que te guste. Aprender a tocar una canción que te gusta te ayudará a mantenerte motivado.
Empieza con un nivel de dificultad fácil. No te preocupes por aprender todo de una vez. Empieza con un nivel de dificultad fácil y ve aumentando la dificultad a medida que avances.
Practica regularmente. La práctica es la clave para aprender a tocar el piano. Practica al menos 30 minutos al día para ver resultados.''']

# %%
print(docs)
# Out:
# ['Synthesia IA es una nueva versión de Synthesia que utiliza inteligencia artificial para mejorar la experiencia de aprendizaje. El programa utiliza un modelo de aprendizaje automático para generar una visualización de las notas que se están tocando en tiempo real, así como una versión sintética del sonido del piano.\nCómo funciona Synthesia IA\nSynthesia IA utiliza un modelo de aprendizaje automático llamado DeepMind Magenta. Este modelo funciona aprendiendo patrones en los vídeos de personas tocando el piano, así como en las grabaciones de audio de piano.\nCuando un usuario toca una nota en el piano, el modelo genera una visualización de la nota que se está tocando. La visualización se muestra en la pantalla del ordenador o del dispositivo móvil del usuario. El modelo también genera una versión sintética del sonido del piano, que se reproduce a través de los altavoces del ordenador o del dispositivo móvil del usuario.\nPasos para usar Synthesia IA\nPara usar Synthesia IA, los usuar
# ...

# %%
# INDEXDIR = '/tmp/myindex'
INDEXDIR = '/tmp/myindex3'
text.SimpleQA.initialize_index(INDEXDIR)
text.SimpleQA.index_from_list(docs,INDEXDIR,commit_every=len(docs))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
qa = text.SimpleQA(INDEXDIR)

# %%
answers = qa.ask('ejemplos de uso Synthesia')
qa.display_answers(answers[:5])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Candidate Answer</th>
#       <th>Context</th>
#       <th>Confidence</th>
#       <th>Document Reference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
answers = qa.ask('pasos para emplear Synthesia')
qa.display_answers(answers[:5])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Candidate Answer</th>
#       <th>Context</th>
#       <th>Confidence</th>
#       <th>Document Reference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
answers = qa.ask('cuáles son los beneficios de Synthesia')
qa.display_answers(answers[:5])
